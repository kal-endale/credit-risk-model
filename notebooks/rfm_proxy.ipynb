# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid", palette="deep")
pd.set_option("display.max_columns", None)

root_dir = Path.cwd()

if root_dir.name == "notebooks":
    root_dir = root_dir.parent

modeling_path = (
    root_dir / "data" / "processed" / "modeling_dataset.csv"
)
profile_path = (
    root_dir / "data" / "processed" / "rfm_cluster_profile.csv"
)

modeling_df = pd.read_csv(modeling_path)
cluster_profile = pd.read_csv(profile_path)

print(f"Customers loaded: {len(modeling_df):,}")
display(cluster_profile)
